# %%
# revenue in USD to NPR (1 USD = 150 NPR)
revs = [[200, 220, 250], [68, 75, 105], [110, 140, 180], [80, 85, 90]]

# %%
import numpy as np

# %%
revs_nrs = np.dot(150, revs)
revs_nrs
# Out:
# array([[30000, 33000, 37500],
#        [10200, 11250, 15750],
#        [16500, 21000, 27000],
#        [12000, 12750, 13500]])
